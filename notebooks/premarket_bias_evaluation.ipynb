# %% [markdown]
# # Premarket Bias Evaluation
#
# Starter notebook for evaluating bias accuracy and calibration.

# %%
# parameters
LOOKBACK_DAYS = 90
SYMBOLS = ['SPY', 'QQQ', 'IWM']

# %%
from datetime import datetime, timezone

print('TODO: compare predicted bias vs realized intraday direction')
print(f'LOOKBACK_DAYS={LOOKBACK_DAYS}, SYMBOLS={SYMBOLS}, run_ts={datetime.now(timezone.utc).isoformat()}')

# %% [markdown]
# ## Planned export
#
# - `llm_advisor_bias_accuracy_90d`
