# %% [markdown]
# # Prompt Ablation
#
# Starter notebook for comparing prompt-version outcomes.

# %%
# parameters
LOOKBACK_DAYS = 60
PROMPT_VERSIONS = ['v1', 'v2', 'v3']

# %%
from datetime import datetime, timezone

print('TODO: compare trade outcomes grouped by prompt_hash/version')
print(f'LOOKBACK_DAYS={LOOKBACK_DAYS}, PROMPT_VERSIONS={PROMPT_VERSIONS}, run_ts={datetime.now(timezone.utc).isoformat()}')

# %% [markdown]
# ## Status
#
# Scaffold only until prompt-version tagging is consistently available in production data.
