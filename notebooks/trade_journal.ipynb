# %% [markdown]
# # Trade Journal
#
# Starter notebook for trade-by-trade narrative output.

# %%
# parameters
LOOKBACK_DAYS = 30
SYMBOL = None

# %%
from datetime import datetime, timezone

print('TODO: query llm_advisor_backtest_trades and llm responses for context')
print(f'LOOKBACK_DAYS={LOOKBACK_DAYS}, SYMBOL={SYMBOL}, run_ts={datetime.now(timezone.utc).isoformat()}')

# %% [markdown]
# ## Planned exports
#
# - `llm_advisor_trades_total_30d`
# - `llm_advisor_win_rate_30d`
# - Weekly markdown artifact for `docs/trade-journal/`
