# %% [markdown]
# # LLM Advisor Evaluation Template
#
# Use this template for new notebook analyses.

# %%
# parameters
LOOKBACK_DAYS = 30
SYMBOL = None
RUN_DATE = None

# %%
from datetime import datetime, timezone

asof = datetime.now(timezone.utc).isoformat()
print(f'Notebook template run at {asof}')
print(f'LOOKBACK_DAYS={LOOKBACK_DAYS}, SYMBOL={SYMBOL}')

# %% [markdown]
# ## Export hook
#
# Add `write_project_metric` exports in the final implementation pass.
