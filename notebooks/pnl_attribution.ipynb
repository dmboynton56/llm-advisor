# %% [markdown]
# # PnL Attribution
#
# Starter notebook for PnL decomposition by symbol, arm, and exit reason.

# %%
# parameters
LOOKBACK_DAYS = 90

# %%
from datetime import datetime, timezone

print('TODO: aggregate pnl by symbol, strategy arm, and exit reason')
print(f'LOOKBACK_DAYS={LOOKBACK_DAYS}, run_ts={datetime.now(timezone.utc).isoformat()}')

# %% [markdown]
# ## Planned exports
#
# - `llm_advisor_pnl_90d_total`
# - `llm_advisor_pnl_by_arm`
# - `llm_advisor_pnl_by_exit_reason`
# - `llm_advisor_sharpe_30d`
