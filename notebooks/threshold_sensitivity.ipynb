# %% [markdown]
# # Threshold Sensitivity
#
# Starter notebook for MR/TC threshold sensitivity sweeps.

# %%
# parameters
LOOKBACK_DAYS = 180
SYMBOLS = ['SPY', 'QQQ', 'IWM']

# %%
from datetime import datetime, timezone

print('TODO: run grid search over mr_arm_z, tc_arm_z, atr SL multiplier')
print(f'LOOKBACK_DAYS={LOOKBACK_DAYS}, SYMBOLS={SYMBOLS}, run_ts={datetime.now(timezone.utc).isoformat()}')

# %% [markdown]
# ## Planned outputs
#
# - Sharpe heatmap
# - Current production thresholds highlighted
# - Recommendation summary
